# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# ...
# WARNING: You are using pip version 19.2.3, however version 20.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...

# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from citipy import citipy

# Import API key
from api_keys import weather_api_key

# Output File (CSV)
w_file = "output_data/weather-data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

# Assign counters as ints
counter = 0
set_one = 1

# %% [markdown]
# ## Generate Cities List

# %%
# Generate cities list including countries and coordinates
cities = []
countries = []
lat_lngs = []

# Create a set of random lat and lng combinations to fill the list
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each coordinates combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to cities list
    if city not in cities:
        cities.append(city)
        countries.append(country.upper())
        numbers.append(number)

# Find number of unique cities 
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
lngs = []
max_temps = []
wind_speeds = []
countries = []
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []

# Set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        number.append(response['sys']['id'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city} | {country}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | bethel | br
# Processing Record 2 of Set 1 | cape town | br
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 1 | lasa | br
# Processing Record 4 of Set 1 | bambous virieux | br
# City not found. Skipping...
# Processing Record 5 of Set 1 | vaini | br
# Processing Record 6 of Set 1 | provideniya | br
# Processing Record 7 of Set 1 | ushuaia | br
# City not found. Skipping...
# Processing Record 8 of Set 1 | kushima | br
# City not found. Skipping...
# Processing Record 9 of Set 1 | yellowknife | br
# Processing Record 10 of Set 1 | klaksvik | br
# Processing Record 11 of Set 1 | hilo | br
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 1 | mataura | br
# Processing Record 13 of Set 1 | jamestown | br
# Processing Record 14 of Set 1 | busselton | br
# Processing Record 15 of Set 1 | nueva gorgona | br
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Windspeed":wind_speeds
}

# %%
#Convert to pandas dataframe and assign as variable for plotting

weather_dataframe = pd.DataFrame(weather_dict)

weather_dataframe.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0        albany         100      US  1603858808        87  42.60 -73.97
# 1  komsomolskiy         100      UZ  1603859178        57  40.43  71.72
# 2  puerto ayora           0      ES  1603858848        81  36.59  -6.23
# 3       qaanaaq          96      GL  1603858848        82  77.48 -69.36
# 4       sorland          20      NO  1603858848        86  67.67  12.69
#
#    Max Temp  Windspeed
# 0     44.01       0.45
# 1     50.00       6.93
# 2     53.60       5.82
# 3     13.50      12.15
# 4     41.00       2.24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Scatter plot Max Temperature vs. Latitude
temp_v_lat = weather_dataframe.plot.scatter(x='Lat',
                      y='Max Temp',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Max Temperature ')
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Max Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Scatter plot Humidity vs. Latitude
temp_v_hum = weather_dataframe.plot.scatter(x='Lat',
                      y='Humidity',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Humidity ')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Scatter plot Cloudiness vs. Latitude
temp_v_clo = weather_dataframe.plot.scatter(x='Lat',
                      y='Cloudiness',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Cloudiness')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Scatter plot Wind Speed vs. Latitude
temp_v_win = weather_dataframe.plot.scatter(x='Lat',
                      y='Windspeed',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Windspeed')
plt.ylabel("Windspeed")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# Perform a linear regression on temperature vs. latitude
# Y = bx + a
# temperature = (slope * latitude) + intercept
# weight = (slope * height) * intercept

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(city_weather_df["Lat"], dfn)

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
