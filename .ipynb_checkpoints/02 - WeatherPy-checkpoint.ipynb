# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\jonat\desktop\bootcamp\bootcamp\lib\site-packages (0.0.5)
# WARNING: You are using pip version 19.2.3, however version 20.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: kdtree>=0.12 in c:\users\jonat\desktop\bootcamp\bootcamp\lib\site-packages (from citipy) (0.16)

# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from citipy import citipy

# Import API key
from api_keys import weather_api_key

# Output File (CSV)
w_file = "Output/CityWeatherData.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

# Assign counters as ints
counter = 0
set_one = 1

# %% [markdown]
# ## Generate Cities List

# %%
# Generate cities list including countries and coordinates
cities = []
countries = []
lat_lngs = []

# Create a set of random lat and lng combinations to fill the list
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each coordinates combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to cities list
    if city not in cities:
        cities.append(city)
        countries.append(country.upper())


# Find number of unique cities 
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set lists for the dataframe
lngs = []
max_temps = []
wind_speeds = []
countries = []
city_two = []
cloudinesses = []
humidities = []
lats = []

# Set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city} | {country}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | kapaa | us
# Processing Record 2 of Set 1 | lorengau | us
# Processing Record 3 of Set 1 | isangel | us
# City not found. Skipping...
# Processing Record 4 of Set 1 | bereda | us
# Processing Record 5 of Set 1 | chuy | us
# Processing Record 6 of Set 1 | atuona | us
# Processing Record 7 of Set 1 | ushuaia | us
# Processing Record 8 of Set 1 | busselton | us
# Processing Record 9 of Set 1 | cape town | us
# Processing Record 10 of Set 1 | hobart | us
# Processing Record 11 of Set 1 | aklavik | us
# City not found. Skipping...
# Processing Record 12 of Set 1 | mar del plata | us
# Processing Record 13 of Set 1 | albany | us
# Processing Record 14 of Set 1 | domoni | us
# Processing Record 15 of Set 1 | san patricio | us
# City not found. Skipping...
# Processing Record 16 of Set 1 | kodiak | us
# Processing Record 17 of Set 1 | tripoli | us
# Processing Record 18 of Set 1 | cam ranh | us
# Processing Record 19 of Set 1 | nikolskoye | us
# Processing Record 20 of Set 1 | bredasdorp | us
# Processing Record 21 of Set 1 | severo-kurilsk | us
# Processing Record 22 of Set 1 | bluff | us
# Processing Record 23 of Set 1 | adrar | us
# Processing Record 24 of Set 1 | beringovskiy | us
# Processing Record 25 of Set 1 | karasburg | us
# Processing Record 26 of Set 1 | ixtapa | us
# Processing Record 27 of Set 1 | wajima | us
# Processing Record 28 of Set 1 | tecoanapa | us
# Processing Record 29 of Set 1 | santa marta | us
# Processing Record 30 of Set 1 | copalillo | us
# Processing Record 31 of Set 1 | pushchino | us
# Processing Record 32 of Set 1 | laguna | us
# Processing Record 33 of Set 1 | norman wells | us
# Processing Record 34 of Set 1 | punta arenas | us
# Processing Record 35 of Set 1 | pevek | us
# Processing Record 36 of Set 1 | srisailam | us
# Processing Record 37 of Set 1 | mecca | us
# Processing Record 38 of Set 1 | vaini | us
# Processing Record 39 of Set 1 | dikson | us
# Processing Record 40 of Set 1 | dicabisagan | us
# Processing Record 41 of Set 1 | saint-philippe | us
# Processing Record 42 of Set 1 | passo fundo | us
# Processing Record 43 of Set 1 | khatanga | us
# Processing Record 17 of Set 4 | rudbar | us
# Processing Record 18 of Set 4 | segou | us
# Processing Record 19 of Set 4 | leningradskiy | us
# Processing Record 20 of Set 4 | buraydah | us
# Processing Record 21 of Set 4 | worthington | us
# Processing Record 22 of Set 4 | conner | us
# Processing Record 23 of Set 4 | camacari | us
# Processing Record 24 of Set 4 | kralendijk | us
# Processing Record 25 of Set 4 | saint-augustin | us
# Processing Record 26 of Set 4 | berezovyy | us
# Processing Record 27 of Set 4 | vardo | us
# Processing Record 28 of Set 4 | jalu | us
# Processing Record 29 of Set 4 | foki | us
# Processing Record 30 of Set 4 | marrakesh | us
# Processing Record 31 of Set 4 | michigan city | us
# Processing Record 32 of Set 4 | udgir | us
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 4 | madang | us
# Processing Record 34 of Set 4 | pedasi | us
# Processing Record 35 of Set 4 | brownsville | us
# Processing Record 36 of Set 4 | ambilobe | us
# Processing Record 37 of Set 4 | barrow | us
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 4 | garissa | us
# Processing Record 39 of Set 4 | avarua | us
# Processing Record 40 of Set 4 | san ramon | us
# Processing Record 41 of Set 4 | qasigiannguit | us
# Processing Record 42 of Set 4 | westport | us
# Processing Record 43 of Set 4 | tessalit | us
# Processing Record 44 of Set 4 | pisco | us
# Processing Record 45 of Set 4 | vaitape | us
# Processing Record 46 of Set 4 | guaratinga | us
# Processing Record 47 of Set 4 | abu dhabi | us
# Processing Record 48 of Set 4 | banepa | us
# Processing Record 49 of Set 4 | hasaki | us
# Processing Record 1 of Set 5 | teguise | us
# Processing Record 2 of Set 5 | mareeba | us
# Processing Record 3 of Set 5 | dubbo | us
# Processing Record 4 of Set 5 | bengkulu | us
# Processing Record 5 of Set 5 | hilo | us
# Processing Record 6 of Set 5 | chiungutwa | us
# Processing Record 7 of Set 5 | asyut | us
# Processing Record 8 of Set 5 | karratha | us
# Processing Record 9 of Set 5 | garowe | us
# Processing Record 10 of Set 5 | waipawa | us
# Processing Record 11 of Set 5 | ponta do sol | us
# Processing Record 12 of Set 5 | ranong | us
# Processing Record 13 of Set 5 | kailua | us
# Processing Record 14 of Set 5 | kaitangata | us
# City not found. Skipping...
# Processing Record 15 of Set 5 | maceio | us
# Processing Record 16 of Set 5 | aleksandrovskiy zavod | us
# Processing Record 17 of Set 5 | palafrugell | us
# Processing Record 18 of Set 5 | aleksandrovsk-sakhalinskiy | us
# Processing Record 19 of Set 5 | cururupu | us
# Processing Record 20 of Set 5 | kamaishi | us
# Processing Record 21 of Set 5 | airai | us
# Processing Record 22 of Set 5 | shimanovsk | us
# Processing Record 23 of Set 5 | saskylakh | us
# Processing Record 24 of Set 5 | tura | us
# Processing Record 25 of Set 5 | bagdarin | us
# Processing Record 26 of Set 5 | synevyr | us
# Processing Record 27 of Set 5 | clyde river | us
# Processing Record 28 of Set 5 | whitehorse | us
# Processing Record 29 of Set 5 | anadyr | us
# Processing Record 30 of Set 5 | koumac | us
# Processing Record 31 of Set 5 | bansang | us
# Processing Record 32 of Set 5 | aksu | us
# Processing Record 33 of Set 5 | borogontsy | us
# City not found. Skipping...
# Processing Record 34 of Set 5 | huarmey | us
# Processing Record 35 of Set 5 | alacranes | us
# Processing Record 36 of Set 5 | leogane | us
# Processing Record 37 of Set 5 | tambovka | us
# Processing Record 38 of Set 5 | zabid | us
# Processing Record 39 of Set 5 | yanam | us
# Processing Record 40 of Set 5 | axim | us
# Processing Record 41 of Set 5 | pouembout | us
# Processing Record 42 of Set 5 | tinskoy | us
# City not found. Skipping...
# Processing Record 43 of Set 5 | primorsk | us
# Processing Record 44 of Set 5 | saldanha | us
# Processing Record 45 of Set 5 | namibe | us
# Processing Record 46 of Set 5 | mahibadhoo | us
# Processing Record 47 of Set 5 | kogon | us
# Processing Record 48 of Set 5 | glendive | us
# Processing Record 49 of Set 5 | elat | us
# Processing Record 1 of Set 6 | paray-le-monial | us
# City not found. Skipping...
# Processing Record 2 of Set 6 | almaznyy | us
# Processing Record 3 of Set 6 | sault sainte marie | us
# Processing Record 4 of Set 6 | plettenberg bay | us
# Processing Record 5 of Set 6 | fortuna | us
# City not found. Skipping...
# Processing Record 6 of Set 6 | yulara | us
# Processing Record 7 of Set 6 | roebourne | us
# Processing Record 8 of Set 6 | tutoia | us
# Processing Record 9 of Set 6 | cockburn town | us
# Processing Record 10 of Set 6 | igarka | us
# Processing Record 11 of Set 6 | honningsvag | us
# City not found. Skipping...
# Processing Record 12 of Set 6 | atar | us
# Processing Record 13 of Set 6 | makakilo city | us
# Processing Record 14 of Set 6 | kapoeta | us
# Processing Record 15 of Set 6 | leninskoye | us
# Processing Record 16 of Set 6 | egvekinot | us
# Processing Record 17 of Set 6 | codrington | us
# Processing Record 18 of Set 6 | kavieng | us
# Processing Record 19 of Set 6 | farah | us
# Processing Record 20 of Set 6 | zamosc | us
# Processing Record 21 of Set 6 | taoudenni | us
# Processing Record 22 of Set 6 | nacala | us
# Processing Record 23 of Set 6 | cherskiy | us
# Processing Record 24 of Set 6 | camacha | us
# City not found. Skipping...
# Processing Record 25 of Set 6 | suntar | us
# Processing Record 26 of Set 6 | upata | us
# Processing Record 27 of Set 6 | berlevag | us
# Processing Record 28 of Set 6 | menongue | us
# Processing Record 29 of Set 6 | malakal | us
# Processing Record 30 of Set 6 | at-bashi | us
# Processing Record 31 of Set 6 | kununurra | us
# Processing Record 32 of Set 6 | hun | us
# Processing Record 33 of Set 6 | mount gambier | us
# Processing Record 34 of Set 6 | moose factory | us
# Processing Record 35 of Set 6 | port elizabeth | us
# Processing Record 36 of Set 6 | ilulissat | us
# Processing Record 37 of Set 6 | riyadh | us
# Processing Record 38 of Set 6 | katsuura | us
# Processing Record 39 of Set 6 | souillac | us
# Processing Record 40 of Set 6 | nesbyen | us
# Processing Record 41 of Set 6 | sao joao da barra | us
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 6 | neuquen | us
# Processing Record 43 of Set 6 | rocha | us
# Processing Record 44 of Set 6 | krasnoselkup | us
# Processing Record 45 of Set 6 | kawana waters | us
# Processing Record 46 of Set 6 | jiangyou | us
# Processing Record 47 of Set 6 | vanimo | us
# Processing Record 48 of Set 6 | itarema | us
# Processing Record 49 of Set 6 | ostrovnoy | us
# Processing Record 1 of Set 7 | mount isa | us
# City not found. Skipping...
# Processing Record 2 of Set 7 | okato | us
# Processing Record 3 of Set 7 | fort nelson | us
# Processing Record 4 of Set 7 | santa rosa | us
# City not found. Skipping...
# Processing Record 5 of Set 7 | nuuk | us
# Processing Record 6 of Set 7 | hamilton | us
# Processing Record 7 of Set 7 | shingu | us
# Processing Record 8 of Set 7 | mahina | us
# City not found. Skipping...
# Processing Record 9 of Set 7 | bilasipara | us
# City not found. Skipping...
# Processing Record 10 of Set 7 | srednekolymsk | us
# Processing Record 11 of Set 7 | stawell | us
# Processing Record 12 of Set 7 | nanortalik | us
# Processing Record 13 of Set 7 | acapulco | us
# Processing Record 14 of Set 7 | vila velha | us
# Processing Record 15 of Set 7 | huilong | us
# Processing Record 16 of Set 7 | kargat | us
# Processing Record 17 of Set 7 | joshimath | us
# Processing Record 18 of Set 7 | broome | us
# Processing Record 19 of Set 7 | tianpeng | us
# Processing Record 20 of Set 7 | bundaberg | us
# Processing Record 21 of Set 7 | svatove | us
# Processing Record 22 of Set 7 | margate | us
# Processing Record 23 of Set 7 | brits | us
# Processing Record 24 of Set 7 | santa elena | us
# Processing Record 25 of Set 7 | hervey bay | us
# Processing Record 26 of Set 7 | lokomotivnyy | us
# City not found. Skipping...
# Processing Record 27 of Set 7 | bijie | us
# Processing Record 28 of Set 7 | olavarria | us
# Processing Record 29 of Set 7 | salalah | us
# Processing Record 30 of Set 7 | tasiilaq | us
# Processing Record 31 of Set 7 | chapais | us
# Processing Record 32 of Set 7 | thompson | us
# Processing Record 33 of Set 7 | kerman | us
# Processing Record 34 of Set 7 | mlimba | us
# Processing Record 35 of Set 7 | boddam | us
# Processing Record 36 of Set 7 | harwich | us
# Processing Record 37 of Set 7 | vestmannaeyjar | us
# Processing Record 38 of Set 7 | mayo | us
# Processing Record 39 of Set 7 | sorland | us
# Processing Record 40 of Set 7 | ridgecrest | us
# Processing Record 41 of Set 7 | deder | us
# Processing Record 42 of Set 7 | papara | us
# City not found. Skipping...
# Processing Record 43 of Set 7 | sabathu | us
# Processing Record 44 of Set 7 | crestview | us
# Processing Record 45 of Set 7 | cahabon | us
# Processing Record 46 of Set 7 | mizdah | us
# Processing Record 47 of Set 7 | grand river south east | us
# Processing Record 48 of Set 7 | jurado | us
# City not found. Skipping...
# Processing Record 49 of Set 7 | mogadishu | us
# Processing Record 1 of Set 8 | iiyama | us
# Processing Record 2 of Set 8 | puerto leguizamo | us
# Processing Record 3 of Set 8 | namatanai | us
# Processing Record 4 of Set 8 | iqaluit | us
# Processing Record 5 of Set 8 | taltal | us
# City not found. Skipping...
# Processing Record 6 of Set 8 | naze | us
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set
# City not found. Skipping...
# Processing Record 17 of Set 9 | ituporanga | us
# Processing Record 18 of Set 9 | aizawl | us
# Processing Record 19 of Set 9 | duki | us
# Processing Record 20 of Set 9 | aktash | us
# Processing Record 21 of Set 9 | buriti | us
# Processing Record 22 of Set 9 | ust-kuyga | us
# Processing Record 23 of Set 9 | hualmay | us
# City not found. Skipping...
# Processing Record 24 of Set 9 | tezu | us
# Processing Record 25 of Set 9 | kalianget | us
# Processing Record 26 of Set 9 | kismayo | us
# Processing Record 27 of Set 9 | formoso do araguaia | us
# Processing Record 28 of Set 9 | bondowoso | us
# City not found. Skipping...
# Processing Record 29 of Set 9 | santa maria | us
# City not found. Skipping...
# Processing Record 30 of Set 9 | dzerzhinsk | us
# Processing Record 31 of Set 9 | baker city | us
# Processing Record 32 of Set 9 | sinnamary | us
# Processing Record 33 of Set 9 | tazovskiy | us
# Processing Record 34 of Set 9 | tabuk | us
# Processing Record 35 of Set 9 | gumdag | us
# City not found. Skipping...
# Processing Record 36 of Set 9 | darhan | us
# Processing Record 37 of Set 9 | bonavista | us
# Processing Record 38 of Set 9 | samana | us
# Processing Record 39 of Set 9 | remontnoye | us
# Processing Record 40 of Set 9 | lander | us
# Processing Record 41 of Set 9 | samarai | us
# Processing Record 42 of Set 9 | naini tal | us
# Processing Record 43 of Set 9 | izazi | us
# Processing Record 44 of Set 9 | kharan | us
# Processing Record 45 of Set 9 | yar-sale | us
# Processing Record 46 of Set 9 | palmer | us
# Processing Record 47 of Set 9 | tekeli | us
# Processing Record 48 of Set 9 | coahuayana | us
# Processing Record 49 of Set 9 | surt | us
# Processing Record 1 of Set 10 | guaratuba | us
# Processing Record 2 of Set 10 | kelvington | us
# Processing Record 3 of Set 10 | atbasar | us
# Processing Record 4 of Set 10 | amapa | us
# Processing Record 5 of Set 10 | lasa | us
# Processing Record 6 of Set 10 | ngunguru | us
# Processing Record 7 of Set 10 | tupiza | us
# Processing Record 8 of Set 10 | pilar | us
# Processing Record 9 of Set 10 | hwange | us
# City not found. Skipping...
# Processing Record 10 of Set 10 | longhua | us
# Processing Record 11 of Set 10 | halapitan | us
# City not found. Skipping...
# Processing Record 12 of Set 10 | metu | us
# City not found. Skipping...
# Processing Record 13 of Set 10 | olafsvik | us
# Processing Record 14 of Set 10 | ayan | us
# Processing Record 15 of Set 10 | sukhinichi | us
# Processing Record 16 of Set 10 | pemangkat | us
# City not found. Skipping...
# Processing Record 17 of Set 10 | cermik | us
# Processing Record 18 of Set 10 | porto nacional | us
# City not found. Skipping...
# Processing Record 19 of Set 10 | santa cruz | us
# Processing Record 20 of Set 10 | verkhnyaya inta | us
# Processing Record 21 of Set 10 | beyneu | us
# Processing Record 22 of Set 10 | ndjole | us
# Processing Record 23 of Set 10 | san policarpo | us
# Processing Record 24 of Set 10 | eastbourne | us
# Processing Record 25 of Set 10 | fairbanks | us
# Processing Record 26 of Set 10 | ust-ilimsk | us
# Processing Record 27 of Set 10 | shimsk | us
# Processing Record 28 of Set 10 | constantine | us
# Processing Record 29 of Set 10 | port lavaca | us
# Processing Record 30 of Set 10 | nagorsk | us
# Processing Record 31 of Set 10 | leshukonskoye | us
# Processing Record 32 of Set 10 | ende | us
# Processing Record 33 of Set 10 | lensk | us
# Processing Record 34 of Set 10 | loralai | us
# Processing Record 35 of Set 10 | gull lake | us
# Processing Record 36 of Set 10 | hohhot | us
# Processing Record 37 of Set 10 | bambous virieux | us
# Processing Record 38 of Set 10 | carutapera | us
# Processing Record 39 of Set 10 | nizwa | us
# Processing Record 40 of Set 10 | muskegon | us
# Processing Record 41 of Set 10 | gejiu | us
# Processing Record 42 of Set 10 | prado | us
# Processing Record 43 of Set 10 | clovis | us
# Processing Record 44 of Set 10 | ergani | us
# Processing Record 45 of Set 10 | ngozi | us
# Processing Record 46 of Set 10 | kurilsk | us
# Processing Record 47 of Set 10 | synya | us
# Processing Record 48 of Set 10 | tomatlan | us
# Processing Record 49 of Set 10 | boyolangu | us
# Processing Record 1 of Set 11 | kedrovyy | us
# Processing Record 2 of Set 11 | paramonga | us
# Processing Record 3 of Set 11 | belfast | us
# Processing Record 4 of Set 11 | alice springs | us
# Processing Record 5 of Set 11 | klyuchevskiy | us
# Processing Record 6 of Set 11 | vryheid | us
# Processing Record 7 of Set 11 | vangaindrano | us
# Processing Record 8 of Set 11 | korsor | us
# Processing Record 9 of Set 11 | yumen | us
# Processing Record 10 of Set 11 | guiratinga | us
# City not found. Skipping...
# Processing Record 11 of Set 11 | demba | us
# Processing Record 12 of Set 11 | san quintin | us
# Processing Record 13 of Set 11 | khandyga | us
# Processing Record 14 of Set 11 | kavaratti | us
# Processing Record 15 of Set 11 | coihaique | us
# Processing Record 16 of Set 11 | berbera | us
# Processing Record 17 of Set 11 | north bend | us
# Processing Record 18 of Set 11 | porterville | us
# Processing Record 19 of Set 11 | sobolevo | us
# Processing Record 20 of Set 11 | muriwai beach | us
# Processing Record 21 of Set 11 | naples | us
# City not found. Skipping...
# Processing Record 22 of Set 11 | muroto | us
# Processing Record 23 of Set 11 | yinchuan | us
# Processing Record 24 of Set 11 | hambantota | us
# Processing Record 25 of Set 11 | choix | us
# Processing Record 26 of Set 11 | pavlovka | us
# Processing Record 27 of Set 11 | kurri kurri | us
# Processing Record 28 of Set 11 | worland | us
# Processing Record 29 of Set 11 | luwuk | us
# Processing Record 30 of Set 11 | fare | us
# Processing Record 31 of Set 11 | soyo | us
# Processing Record 32 of Set 11 | hirara | us
# City not found. Skipping...
# Processing Record 33 of Set 11 | kem | us
# Processing Record 34 of Set 11 | nantucket | us
# Processing Record 35 of Set 11 | kloulklubed | us
# City not found. Skipping...
# Processing Record 36 of Set 11 | ust-kut | us
# Processing Record 37 of Set 11 | talara | us
# Processing Record 38 of Set 11 | aflao | us
# City not found. Skipping...
# Processing Record 39 of Set 11 | alyangula | us
# Processing Record 40 of Set 11 | lucenec | us
# Processing Record 41 of Set 11 | dunmore east | us
# City not found. Skipping...
# Processing Record 42 of Set 11 | pimenta bueno | us
# Processing Record 43 of Set 11 | hailar | us
# Processing Record 44 of Set 11 | lao cai | us
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary for dataframe
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Windspeed":wind_speeds
}

# %%
#Convert to pandas dataframe and assign as variable for plotting


weather_dataframe = pd.DataFrame(weather_dict)

weather_dataframe.to_csv("Output/CityWeatherData.csv")


weather_dataframe
# Out:
#               City  Cloudiness Country  Humidity    Lat     Lng  Max Temp  \
# 0            kapaa          40      US        83  22.08 -159.32     73.40
# 1         lorengau          69      PG        70  -2.02  147.27     84.45
# 2          isangel          25      VU        71 -19.55  169.27     77.63
# 3           bereda          80      ES       100  43.27   -7.54     52.00
# 4             chuy         100      UY        97 -33.70  -53.46     62.08
# ..             ...         ...     ...       ...    ...     ...       ...
# 529        lucenec          20      SK       100  48.33   19.67     44.60
# 530   dunmore east          90      US        62  41.42  -75.63     51.80
# 531  pimenta bueno          13      BR        84 -20.48  -45.80     68.29
# 532         hailar           1      CN        71  49.20  119.70     34.86
# 533        lao cai          15      PH        65  11.02  124.56     87.46
#
#      Windspeed
# 0         8.05
# 1         0.98
# 2        17.45
# 3         8.01
# 4         8.39
# ..         ...
# 529       1.12
# 530       3.36
# 531       2.08
# 532      12.33
# 533       2.62
#
# [534 rows x 8 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Scatter plot Max Temperature vs. Latitude
temp_v_lat = weather_dataframe.plot.scatter(x='Lat',
                      y='Max Temp',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Max Temperature ')
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Max Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Scatter plot Humidity vs. Latitude
temp_v_hum = weather_dataframe.plot.scatter(x='Lat',
                      y='Humidity',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Humidity ')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Scatter plot Cloudiness vs. Latitude
temp_v_clo = weather_dataframe.plot.scatter(x='Lat',
                      y='Cloudiness',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Cloudiness')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Scatter plot Wind Speed vs. Latitude
temp_v_win = weather_dataframe.plot.scatter(x='Lat',
                      y='Windspeed',
                      c='Blue',
                          grid=True)

#Add title with dynamic date and change axis labels
plt.title(f'City Latitude vs. Windspeed')
plt.ylabel("Windspeed")
plt.xlabel("Latitude")
plt.grid(True)

#Export graph as png
plt.savefig("Output/City Latitude vs. Windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# Perform a linear regression on temperature vs. latitude
# Y = bx + a
# temperature = (slope * latitude) + intercept
# weight = (slope * height) * intercept

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(city_weather_df["Lat"], dfn)

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
